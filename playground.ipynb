# %%
from typing import List, Self
import pydantic, os, dotenv, PyPDF2, chromadb, chromadb.config, chromadb.utils.embedding_functions
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

dotenv.load_dotenv()
# Out:
# True

# %%
ChatGoogleGenerativeAI(model="gemini-2.5-flash-preview-05-20", temperature=0.7).invoke("Hey")
# Out:
# AIMessage(content='Hey there! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash-latest', 'safety_ratings': []}, id='run--82b2aa09-71a7-4a07-8f4e-e8cd7737bcf3-0', usage_metadata={'input_tokens': 1, 'output_tokens': 11, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %%
emb = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004").embed_query("cats")
len(emb), emb[:2]  # Size 768
# Out:
# (768, [-0.03150507062673569, -0.001939397887326777])

# %%
chroma_compatible_google_ef = chromadb.utils.embedding_functions.ChromaLangchainEmbeddingFunction(
    embedding_function = GoogleGenerativeAIEmbeddings(
        model = "models/text-embedding-004"
    )
)

client = chromadb.PersistentClient(path=os.path.join(os.getcwd(), "database", "chroma_db"))

documents = client.get_or_create_collection(
    name="documents",
    embedding_function=chroma_compatible_google_ef
)
titles = client.get_or_create_collection(
    name="titles",
    embedding_function=chroma_compatible_google_ef
)

# %%
def load_documents() -> List[str]:
    documents = []
    documents_dir = os.path.join(os.getcwd(), "database", "documents")
    for filename in os.listdir(documents_dir):
        if filename.endswith(".txt") or filename.endswith(".md") or filename.endswith(".html"):
            with open(os.path.join(documents_dir, filename), "r", encoding="utf-8") as file:
                documents.append(file.read())
        elif filename.endswith(".pdf"):
            with open(os.path.join(documents_dir, filename), "rb") as file:
                reader = PyPDF2.PdfReader(file)
                text = "\n".join([page.extract_text() for page in reader.pages if page.extract_text()])
                documents.append(text)
    return documents

# %%
if True:
    documents.delete([f"doc_{i+1}" for i in range(documents.count())])
    titles.delete([f"doc_{i+1}" for i in range(titles.count())])

# %%
if True:
    docs = load_documents()
    
    generate_title = lambda doc: ChatGoogleGenerativeAI(
            model="gemini-2.5-flash-preview-05-20",
            temperature=0.7
        ).invoke(
            "Generate a title for the following document in the language of said document. "
            + f"Only output the title and nothing else. Document:\n\n{doc}"
        ).content
    
    documents.add(documents=docs, ids=[f"doc_{i+1}" for i in range(len(docs))])
    titles.add(documents=[generate_title(doc) for doc in docs], ids=[f"doc_{i+1}" for i in range(len(docs))])
    
documents.count()
# Out:
# 9

# %%
documents.query(
    query_texts=["chats"],
    n_results=3,
)
# Out:
# {'ids': [['doc_2', 'doc_4', 'doc_5']],
#  'embeddings': None,
#  'documents': [[' \nDéroulement\n \nTX\n \n \nPhase\n \nExploratoire\n \n \nPendant\n \nles\n \ndeux\n \npremières\n \nsemaines,\n \nnous\n \nétudions\n \nles\n \ndifférents\n \nservices\n \npossibles\n \nqui\n \npourraient\n \npermettre\n \nde\n \ntirer\n \npartie\n \ndes\n \nmodèles\n \nde\n \nlangage\n \npour\n \nles\n \nactivités\n \nquotidiennes\n \nà\n \nl’UTC.\n \n \nOn\n \nréfléchit\n \naux\n \ndifférentes\n \nproblématiques\n \nauxquelles\n \nla\n \ntechnologie\n \nse\n \nprête\n \net\n \non\n \névalue\n \nen\n \ndirect\n \nla\n \nfaisabilité\n \nde\n \nnos\n \nidées,\n \nalors\n \nque\n \nnous\n \ndécouvrons\n \nles\n \ntechnologies\n \ndisponibles.\n \n \nOn\n \ns’arrête\n \nnotamment\n \nsur\n \nl’idée\n \nde\n \ncréer\n \nun\n \nagent\n \nqui\n \npourrait\n \ntirer\n \npartie\n \nde\n \nla\n \ndocumentation\n \nde\n \nla\n \nDSI\n \npour\n \nassister\n \nles\n \nutilisateurs.\n \n \nEtablissement\n \ndes\n \nContraintes\n \nde\n \nl’Agent\n \n \nUne\n \nproblématique\n \nsimple\n \nqui\n \nnous\n \na\n \nété\n \nprésentée\n \n:\n \nLa\n \nDSI\n \nfait\n \nface\n \nà\n \nun\n \ngrand\n \nnombre\n \nde\n \ntickets\n \net\n \nde\n \ndemandes\n \nd’utilisateurs,\n \ndont\n \nune\n \npart\n \nsubstantielle\n \nde\n \nréponses\n \nse\n \ntrouve\n \ndéjà\n \nexpliquée\n \ndans\n \ndivers\n \ndocuments\n \nmis\n \nà\n \ndisposition\n \nsur\n \nl’intranet\n \nUTC.\n \n \nCes\n \ndocuments\n \nsont\n \nrelativement\n \npeu\n \ncentralisés\n \net\n \nparfois\n \nlacunaires,\n \nla\n \ndocumentation\n \ntechnique\n \nmise\n \nà\n \ndisposition\n \ndes\n \nmembres\n \nde\n \nl’UTC\n \npourrait\n \nêtre\n \nretravaillée.\n \nCette\n \ntâche\n \nsortirait\n \ndu\n \ncadre\n \nde\n \nla\n \nTX.\n \n \nUne\n \nexploitation\n \ndirecte\n \ndes\n \ntechnologies\n \nd’agents\n \nconversationnels\n \nque\n \nnous\n \navons\n \nexplorées\n \nprécédemment\n \nserait\n \nde\n \nconstruire\n \nun\n \nagent\n \nqui\n \ninterpréterais\n \nle\n \nproblème\n \nde\n \nl’utilisateur\n \net\n \nrécupérerais\n \ndes\n \nréférences\n \npertinentes\n \ndans\n \nla\n \ndocumentation\n \npour\n \nl’aider\n \nà\n \nrésoudre\n \nson\n \nproblème.\n \n \nDans\n \ncette\n \nsituation,\n \nl’agent\n \ndoit\n \nservir\n \nidéalement\n \ntoute\n \npersonne\n \nqui\n \naurait\n \nun\n \nproblème\n \ninformatique\n \nau\n \nsein\n \nde\n \nl’UTC,\n \nl’agent\n \ndoit\n \ndonc\n \nêtre\n \ndisponible\n \ncomme\n \nun\n \nservice\n \nà\n \nun\n \ngrand\n \nnombre.\n \n(contrainte\n \nSERVICE)\n \n \nPuisqu’il\n \ns’agit\n \nd’un\n \nservice\n \nqui\n \nrisque\n \nd’utiliser\n \ndes\n \ndonnées\n \nprivées,\n \net\n \npour\n \ndes\n \nraisons\n \nde\n \ncoûts,\n \nnous\n \nsouhaitons\n \nutiliser\n \ndes\n \nmodèles\n \nde\n \nlangage\n \nhébergés\n \nsur\n \nles\n \nserveurs\n \nde\n \nl’UTC\n \n(contrainte\n \nLOCAL),\n \net\n \nlimiter\n \nl’assistance\n \nà\n \ndes\n \nproblématiques\n \nqui\n \nne\n \nnécessitent\n \npas\n \nque\n \nl’utilisateur\n \nfournisse\n \ndes\n \ndonnées\n \nsensibles\n \ndans\n \nla\n \nconversation\n \ntelles\n \nque\n \ndes\n \nmots\n \nde\n \npasse\n \n(contrainte\n \nSENSIBLE)\n \n \nLa\n \ndocumentation\n \nde\n \nla\n \nDSI\n \ndoit\n \navoir\n \nun\n \nrôle\n \nprincipal,\n \nle\n \npersonnel\n \nde\n \nla\n \nDSI\n \ndoit\n \npouvoir\n \nrédiger\n \navec\n \nleurs\n \nmots\n \nune\n \ndocumentation,\n \net\n \nles\n \nutilisateurs\n \ndoivent\n \navoir\n \naccès\n \nà\n \nces\n \ndocuments.\n \nNotre\n \nagent\n \ndoit\n \ndonc\n \nse\n \npositionner\n \ncomme\n \nune\n \ninterface\n \nsur\n \nla\n \ndocumentation\n \nexistante.\n \nAinsi,\n \nil\n \ndoit\n \npouvoir\n \nmentionner\n \nses\n \nsources\n \net\n \ny\n \ndiriger\n \nles\n \nutilisateurs.\n \n(contrainte\n \nCITATION)\n \nImplicitement,\n \nil\n \ndoit\n \nidéalement\n \nse\n \nbaser\n \nsur\n \nla\n \ndocumentation\n \nexistante\n \nou\n \nsur\n \nun\n \nsous-ensemble\n \nde\n \nla\n \ndocumentation\n \nexistante.\n \n(contrainte\n \nSOURCE)\n \n \nTirer\n \n ...
#    '\n## Intention Générale\n\n  \nCe texte propose une exploration phénoménologique et pragmatique de notre rapport au monde, à nous-mêmes et aux autres. Il part du constat que notre expérience subjective (ce que nous percevons, ressentons, pensons, nous souvenons) est le matériau premier et incontournable avec lequel nous opérons pour comprendre, décider et interagir. Loin de nier une potentielle réalité objective, il suggère que pour une réflexion honnête et utile, il est plus fécond de considérer nos connaissances comme des constructions faites à partir de cette expérience. L\'objectif est de développer une conscience accrue de ces mécanismes – comment nous interprétons le passé, anticipons le futur, communiquons – afin d\'identifier les pièges du langage et de la pensée automatique ("boucles langagières"), et de cultiver une manière d\'être et d\'agir plus alignée avec nos aspirations profondes (éviter les situations non désirées, tendre vers celles que nous préférons), en se fondant sur un apprentissage continu ancré dans l\'expérience concrète.\n\n---\n\n# Guide Approfondi : Naviguer l\'Existence par le Prisme de l\'Expérience Consciente\n\n  \nCe guide explore une manière de penser et d\'interagir avec le monde en plaçant l\'expérience vécue et la conscience de nos propres processus mentaux au centre de notre approche.\n\n## I. Le Point de Départ : Le Primat Opérationnel de l\'Expérience Subjective\n\n* Notre Matériau Premier : Que nous le voulions ou non, tout ce à quoi nous avons accès directement pour réfléchir, ressentir et décider provient de notre flux d\'expérience : sensations, émotions, pensées émergentes, souvenirs activés, interprétations des paroles et actes d\'autrui. C\'est la "donnée brute" avec laquelle nous composons notre réalité vécue.\n* Modéliser Plutôt qu\'Affirmer une Réalité Directe : \n  * Nous pouvons tout à fait postuler une réalité objective extérieure. Cependant, pour une réflexion rigoureuse sur comment nous fonctionnons, il est plus juste de traiter notre "compréhension du monde" comme un modèle, qui dépendrait de nos expériences accumulées et influencerait par son usage nos décisions ou plus généralement notre comportement.\n  * Parler du "monde", de "la vérité", etc., sont des raccourcis linguistiques pratiques et intégrés à nos langues, mais qui peuvent masquer le fait que nous parlons toujours depuis notre perspective expérientielle. On pourrait tout reformuler en termes d\'expériences ("J\'ai fait l\'expérience de voir X", "Mon expérience passée me fait anticiper Y"), mais ce serait fastidieux. L\'important est de garder cette nature de "modèle basé sur l\'expérience" à l\'esprit.\n* La Question des Origines (et son Inutilité Pratique) : Peu importe si nos pensées ou souvenirs proviennent "naturellement" de nos interactions ou ont été "injectés" (lavage de cerveau, intervention divine/extraterrestre). Puisque nous n\'avons aucun moyen fiable de distinguer ces sources ultimes, et que nous nous construisons et agissons inévitablement à partir de ce que nous percevons comme nos souvenirs et expériences, la seule approche pragmatique est de travailler avec ce matériau tel qu\'il se présente à nous. Notre inclination naturelle est de réfléchir en ces termes.\n* L\'Hypothèse de l\'Autre : Un Modèle Essentiel : Nous observons les autres, leur ressemblance avec nous, et leurs réactions à nos actions. Par induction et empathie (modélisée), nous supposons qu\'ils fonctionnent sur des bases similaires : leurs paroles et actes découlent de leurs propres expériences internes, états émotionnels, et processus de pensée. C\'est une hypothèse fondamentale pour l\'interaction, bien que nous n\'accédions jamais directement à leur vécu.\n\n## II. Appréhender le Flux Temporel : Passé Rappelé, Futur Anticipé\n\n* Le Passé : Une Reconstruction Pertinente pour le Présent : \n  * Le "passé" n\'est pas une entité fixe que nous consultons. C\'est une reconstruction actuelle basée sur des traces (souvenirs, obj ...
#    '<!DOCTYPE html>\n<!-- saved from url=(0189)https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/ -->\n<html lang="en-US"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\t\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="robots" content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1">\n\t<style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>\n\t\n\t<meta name="description" content="Context and ObjectivesPresident Donald J. Trump and Prime Minister Sir Keir Starmer committed to deliver shared prosperity for American and British">\n\t<link rel="canonical" href="https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/">\n\t<meta property="og:locale" content="en_US">\n\t<meta property="og:type" content="article">\n\t<meta property="og:title" content="General Terms for the United States of America and the United Kingdom of Great Britain and Northern Ireland Economic Prosperity Deal">\n\t<meta property="og:description" content="Context and ObjectivesPresident Donald J. Trump and Prime Minister Sir Keir Starmer committed to deliver shared prosperity for American and British">\n\t<meta property="og:url" content="https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/">\n\t<meta property="og:site_name" content="The White House">\n\t<meta property="article:publisher" content="https://www.facebook.com/WhiteHouse/">\n\t<meta property="article:published_time" content="2025-05-08T23:10:19+00:00">\n\t<meta property="article:modified_time" content="2025-05-09T13:07:13+00:00">\n\t<meta property="og:image" content="https://www.whitehouse.gov/wp-content/uploads/2025/03/WH47-Social-Share-Card.jpg">\n\t<meta property="og:image:width" content="1200">\n\t<meta property="og:image:height" content="628">\n\t<meta property="og:image:type" content="image/jpeg">\n\t<meta name="twitter:card" content="summary_large_image">\n\t<meta name="twitter:creator" content="@whitehouse">\n\t<meta name="twitter:site" content="@whitehouse">\n\t<script type="text/javascript" async="" src="./General Terms for the United States of America and the United Kingdom of Great Britain and Northern Ireland Economic Prosperity Deal – The White House_files/js"></script><script async="" src="./General Terms for the United States of America and the United Kingdom of Great Britain and Northern Ireland Economic Prosperity Deal – The White House_files/gtm.js.télécharger"></script><script type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Article","@id":"https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/#article","isPartOf":{"@id":"https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/"},"headline":"General Terms for the United States of America and the United Kingdom of Great Britain and Northern Ireland Economic Prosperity Deal","datePublished":"2025-05-08T23:10:19+00:00","dateModified":"2025-05-09T13:07:13+00:00","mainEntityOfPage":{"@id":"https://www.whitehouse.gov/briefings-statements/2025/05/general-terms-for-the-united-states-of-america-and-the-united-kingdom-of-great-britain-and-northern-ireland-economic-prosperity-deal/"},"wordCount":1666,"publisher":{"@id":"https://www.whitehouse.gov/#organization"},"articleSection":["Briefings &amp; Statements ...
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None]],
#  'distances': [[0.8443190455436707, 0.8893458247184753, 0.8953454494476318]]}

# %%
class Document(pydantic.BaseModel):
    id: str
    title: str
    content: str

def query(q: str, n_results: int) -> List[Document]:
    document_results = documents.query(
        query_texts=[q],
        n_results=n_results,
    )
    if not document_results:
        return []
    
    ids = document_results["ids"][0]
    titles_results = titles.get(ids=ids)
    return [
        Document(
            id=ids[i],
            title=titles_results["documents"][i],
            content=document_results["documents"][0][i]
        ) for i in range(len(ids))
    ]
    
query("Anything about cats", 3)
# Out:
# [Document(id='doc_3', title='Development of a Conversational Agent for IT Support at UTC using Large Language Models', content="Chat\nNom vulgaire ou nom vernaculaire ambigu :\nl'appellation « Chat » s'applique en français à plusieurs\ntaxons distincts.\nUn Chat de Biet, (Felis bieti)\nTaxons concernés\nDans la famille des Felidae , certaines\nespèces dans les genres:\nFelis\nLeopardus\nOtocolobus\nPardofelis\nPrionailurus\nChat (animal)\nChat  est un terme ambigu employé en français\npour désigner de nombreux félins  de taille\nmoyenne ou petite, appartenant à la sous-famille\ndes félinés . Employé seul, il s'agit du nom\nvernaculaire  donné au chat domestique  (Felis\nsilvestris catus ). Par synecdoque , chat peut\ndésigner l'ensemble des félins  : l'expression « chat\nsauvage  » s'applique à plusieurs espèces ou sous-\nespèces de petits félins, tandis que la sous-famille\ndes Panthérinés  est parfois désignée par\nl'expression « grands chats » .\nListe alphabétique de noms vulgaires  ou de noms\nvernaculaires  attestés  en français.\nNote : certaines espèces ont plusieur s noms et\nfigur ent donc plusieurs fois dans cette liste. Les\nclassifications évoluant encor e, certains noms\nscientifiques ont peut-êtr e un autre synonyme\nvalide.\nChat des Andes  : Oreailurus jacobita\nIl vit dans les Andes, entre le Chili\net le Pérou . Sa robe gris-brun\nargenté, très fournie, lui permet de\nfréquenter les hauts sommets,\njusqu'à 5 000 m.\nChat bai  : Pardofelis badia\nIl vit à Bornéo et se distingue de\nses congénères locaux par une\nrobe uniforme rousse ou brune. Il se nourrit principalement de petits mammifères\ncomme les rongeurs. Son poids se situe entre 2 et 4 kg.\nChat de Biet  (ou chat des déserts de Chine) : Felis bietiListe de noms français de félins\nappelés « chat »\n[1]\nA-C\n[2]\nIl vit dans les steppes de Mongolie  et on le rencontre en montagne, jusqu'à 3 000 m\nd'altitude. Sa robe est pâle, avec des rayures peu prononcées.\nChaus  (ou chat des marais, de jungle) - Felis chaus\nIl vit en Inde, mais on le rencontre jusqu'en Thaïlande , où il s'est spécialisé dans la\nchasse au canard . Ce grand chat vivait auparavant en Afrique .\nChat du Chili  : Leopardus guigna\nPetit félin tacheté des forêts d'Amérique du Sud, deux fois plus petit qu'un chat\ndomestique.\nChat de Chine  : Prionailurus bengalensis\nChat du désert  : Felis margarita\nChat domestique  : Felis silvestris catus\nChat doré africain  : Profelis aurata\nIl vit dans les forêts du bassin du Congo . De taille moyenne, sa robe est brun doré.\nChat doré d'Asie  : Catopuma temminckii\nIl vit en Chine du Sud et en Inde, dans les forêts et les montagnes de basse altitude.\nSon poids dépasse facilement les 10 kg.\nChat ganté  : Felis silvestris lybica\nPetit félin commun dans toute l'Afrique, il porte une robe tabby sur fond jaune. Il\nchasse la nuit et se domestique assez facilement.\nChat du Général Marguerite  : Felis margarita\nChat de Geof froy : Oncifelis geoffroyi\nOn le rencontre de la Bolivie  jusqu'en Patagonie . Il vit dans les arbres et chasse la\nnuit. Sa robe est tabby gris-brun.\nChat haret  : Felis silvestris\nChat d'Iriomote  : Prionailurus bengalensis iriomotensis\nChat léopard du Bengale  : Prionailurus bengalensis\nIl vit en Asie du Sud-Est, en Sibérie , au Tibet et en Chine. D'un poids moyen de 5 kg,\nsa robe ressemble à celle de la panthère  et est considérée comme telle.\nChat léopard de l'Inde  : Prionailurus bengalensis\nChat marbré  : Pardofelis marmorataD\nG-I\nL\nM-O\nIl vit surtout en Birmanie , au Népal  et à Bornéo . De taille moyenne, mais possédant\nde longues pattes, c'est un chasseur d' oiseaux  redoutable. Il adore vivre dans les\narbres, près d'un point d'eau. Sa robe ressemble à celle de la panthère.\nChat de Marguerite  : Felis margarita\nChat de Mongolie  : Felis bieti\nChat des montagnes chinoises  : Felis bieti\nChat orné  (ou chat des steppes)\nIl vit dans les steppes et les forêts de l’ouest de l’Asie jusqu'au désert de ...
#  Document(id='doc_4', title='Liste des noms français de félins appelés « chat »', content='\n## Intention Générale\n\n  \nCe texte propose une exploration phénoménologique et pragmatique de notre rapport au monde, à nous-mêmes et aux autres. Il part du constat que notre expérience subjective (ce que nous percevons, ressentons, pensons, nous souvenons) est le matériau premier et incontournable avec lequel nous opérons pour comprendre, décider et interagir. Loin de nier une potentielle réalité objective, il suggère que pour une réflexion honnête et utile, il est plus fécond de considérer nos connaissances comme des constructions faites à partir de cette expérience. L\'objectif est de développer une conscience accrue de ces mécanismes – comment nous interprétons le passé, anticipons le futur, communiquons – afin d\'identifier les pièges du langage et de la pensée automatique ("boucles langagières"), et de cultiver une manière d\'être et d\'agir plus alignée avec nos aspirations profondes (éviter les situations non désirées, tendre vers celles que nous préférons), en se fondant sur un apprentissage continu ancré dans l\'expérience concrète.\n\n---\n\n# Guide Approfondi : Naviguer l\'Existence par le Prisme de l\'Expérience Consciente\n\n  \nCe guide explore une manière de penser et d\'interagir avec le monde en plaçant l\'expérience vécue et la conscience de nos propres processus mentaux au centre de notre approche.\n\n## I. Le Point de Départ : Le Primat Opérationnel de l\'Expérience Subjective\n\n* Notre Matériau Premier : Que nous le voulions ou non, tout ce à quoi nous avons accès directement pour réfléchir, ressentir et décider provient de notre flux d\'expérience : sensations, émotions, pensées émergentes, souvenirs activés, interprétations des paroles et actes d\'autrui. C\'est la "donnée brute" avec laquelle nous composons notre réalité vécue.\n* Modéliser Plutôt qu\'Affirmer une Réalité Directe : \n  * Nous pouvons tout à fait postuler une réalité objective extérieure. Cependant, pour une réflexion rigoureuse sur comment nous fonctionnons, il est plus juste de traiter notre "compréhension du monde" comme un modèle, qui dépendrait de nos expériences accumulées et influencerait par son usage nos décisions ou plus généralement notre comportement.\n  * Parler du "monde", de "la vérité", etc., sont des raccourcis linguistiques pratiques et intégrés à nos langues, mais qui peuvent masquer le fait que nous parlons toujours depuis notre perspective expérientielle. On pourrait tout reformuler en termes d\'expériences ("J\'ai fait l\'expérience de voir X", "Mon expérience passée me fait anticiper Y"), mais ce serait fastidieux. L\'important est de garder cette nature de "modèle basé sur l\'expérience" à l\'esprit.\n* La Question des Origines (et son Inutilité Pratique) : Peu importe si nos pensées ou souvenirs proviennent "naturellement" de nos interactions ou ont été "injectés" (lavage de cerveau, intervention divine/extraterrestre). Puisque nous n\'avons aucun moyen fiable de distinguer ces sources ultimes, et que nous nous construisons et agissons inévitablement à partir de ce que nous percevons comme nos souvenirs et expériences, la seule approche pragmatique est de travailler avec ce matériau tel qu\'il se présente à nous. Notre inclination naturelle est de réfléchir en ces termes.\n* L\'Hypothèse de l\'Autre : Un Modèle Essentiel : Nous observons les autres, leur ressemblance avec nous, et leurs réactions à nos actions. Par induction et empathie (modélisée), nous supposons qu\'ils fonctionnent sur des bases similaires : leurs paroles et actes découlent de leurs propres expériences internes, états émotionnels, et processus de pensée. C\'est une hypothèse fondamentale pour l\'interaction, bien que nous n\'accédions jamais directement à leur vécu.\n\n## II. Appréhender le Flux Temporel : Passé Rappelé, Futur Anticipé\n\n* Le Passé : Une Reconstruction Pertinente pour le Présent : \n  * Le "passé" n\'est pas une entité fixe que n ...
#  Document(id='doc_2', title="Naviguer l'Existence par le Prisme de l'Expérience Consciente", content=' \nDéroulement\n \nTX\n \n \nPhase\n \nExploratoire\n \n \nPendant\n \nles\n \ndeux\n \npremières\n \nsemaines,\n \nnous\n \nétudions\n \nles\n \ndifférents\n \nservices\n \npossibles\n \nqui\n \npourraient\n \npermettre\n \nde\n \ntirer\n \npartie\n \ndes\n \nmodèles\n \nde\n \nlangage\n \npour\n \nles\n \nactivités\n \nquotidiennes\n \nà\n \nl’UTC.\n \n \nOn\n \nréfléchit\n \naux\n \ndifférentes\n \nproblématiques\n \nauxquelles\n \nla\n \ntechnologie\n \nse\n \nprête\n \net\n \non\n \névalue\n \nen\n \ndirect\n \nla\n \nfaisabilité\n \nde\n \nnos\n \nidées,\n \nalors\n \nque\n \nnous\n \ndécouvrons\n \nles\n \ntechnologies\n \ndisponibles.\n \n \nOn\n \ns’arrête\n \nnotamment\n \nsur\n \nl’idée\n \nde\n \ncréer\n \nun\n \nagent\n \nqui\n \npourrait\n \ntirer\n \npartie\n \nde\n \nla\n \ndocumentation\n \nde\n \nla\n \nDSI\n \npour\n \nassister\n \nles\n \nutilisateurs.\n \n \nEtablissement\n \ndes\n \nContraintes\n \nde\n \nl’Agent\n \n \nUne\n \nproblématique\n \nsimple\n \nqui\n \nnous\n \na\n \nété\n \nprésentée\n \n:\n \nLa\n \nDSI\n \nfait\n \nface\n \nà\n \nun\n \ngrand\n \nnombre\n \nde\n \ntickets\n \net\n \nde\n \ndemandes\n \nd’utilisateurs,\n \ndont\n \nune\n \npart\n \nsubstantielle\n \nde\n \nréponses\n \nse\n \ntrouve\n \ndéjà\n \nexpliquée\n \ndans\n \ndivers\n \ndocuments\n \nmis\n \nà\n \ndisposition\n \nsur\n \nl’intranet\n \nUTC.\n \n \nCes\n \ndocuments\n \nsont\n \nrelativement\n \npeu\n \ncentralisés\n \net\n \nparfois\n \nlacunaires,\n \nla\n \ndocumentation\n \ntechnique\n \nmise\n \nà\n \ndisposition\n \ndes\n \nmembres\n \nde\n \nl’UTC\n \npourrait\n \nêtre\n \nretravaillée.\n \nCette\n \ntâche\n \nsortirait\n \ndu\n \ncadre\n \nde\n \nla\n \nTX.\n \n \nUne\n \nexploitation\n \ndirecte\n \ndes\n \ntechnologies\n \nd’agents\n \nconversationnels\n \nque\n \nnous\n \navons\n \nexplorées\n \nprécédemment\n \nserait\n \nde\n \nconstruire\n \nun\n \nagent\n \nqui\n \ninterpréterais\n \nle\n \nproblème\n \nde\n \nl’utilisateur\n \net\n \nrécupérerais\n \ndes\n \nréférences\n \npertinentes\n \ndans\n \nla\n \ndocumentation\n \npour\n \nl’aider\n \nà\n \nrésoudre\n \nson\n \nproblème.\n \n \nDans\n \ncette\n \nsituation,\n \nl’agent\n \ndoit\n \nservir\n \nidéalement\n \ntoute\n \npersonne\n \nqui\n \naurait\n \nun\n \nproblème\n \ninformatique\n \nau\n \nsein\n \nde\n \nl’UTC,\n \nl’agent\n \ndoit\n \ndonc\n \nêtre\n \ndisponible\n \ncomme\n \nun\n \nservice\n \nà\n \nun\n \ngrand\n \nnombre.\n \n(contrainte\n \nSERVICE)\n \n \nPuisqu’il\n \ns’agit\n \nd’un\n \nservice\n \nqui\n \nrisque\n \nd’utiliser\n \ndes\n \ndonnées\n \nprivées,\n \net\n \npour\n \ndes\n \nraisons\n \nde\n \ncoûts,\n \nnous\n \nsouhaitons\n \nutiliser\n \ndes\n \nmodèles\n \nde\n \nlangage\n \nhébergés\n \nsur\n \nles\n \nserveurs\n \nde\n \nl’UTC\n \n(contrainte\n \nLOCAL),\n \net\n \nlimiter\n \nl’assistance\n \nà\n \ndes\n \nproblématiques\n \nqui\n \nne\n \nnécessitent\n \npas\n \nque\n \nl’utilisateur\n \nfournisse\n \ndes\n \ndonnées\n \nsensibles\n \ndans\n \nla\n \nconversation\n \ntelles\n \nque\n \ndes\n \nmots\n \nde\n \npasse\n \n(contrainte\n \nSENSIBLE)\n \n \nLa\n \ndocumentation\n \nde\n \nla\n \nDSI\n \ndoit\n \navoir\n \nun\n \nrôle\n \nprincipal,\n \nle\n \npersonnel\n \nde\n \nla\n \nDSI\n \ndoit\n \npouvoir\n \nrédiger\n \navec\n \nleurs\n \nmots\n \nune\n \ndocumentation,\n \net\n \nles\n \nutilisateurs\n \ndoivent\n \navoir\n \naccès\n \nà\n \nces\n \ndocuments.\n \nNotre\n \nagent\n \ndoit\n \ndonc\n \nse\n \npositionner\n \ncomme\n \nune\n \ninterface\n \nsur\n \nla\n \ndocumentation\n \nexistante.\n \nAinsi,\n \nil\n \ndoit\n \npouvoir\n \nmentionner\n \nses\n \nsources\n \net\n \ny\n \ndiriger\n \nles\n \nutilisateurs.\n \n(contrainte\n \nCITATION)\n \nImplicitement,\n \nil\n \ndoit\n \nidéalement\n \nse\n \nbaser\n \nsur\n \nla\n \ndocumentation\n \nexistante\n \nou\n \nsur\n \nun\n \nsous-ensemble\n \nde\ ...

# %%
def LLMSummary(q: str) -> str:
    return ChatGoogleGenerativeAI(
        model="gemini-2.5-flash-preview-05-20",
        temperature=0.7
    ).invoke(
        "Summarize the following documents in a single markdown setup. Use markdown freely. "
        + "Use the language of the user query (usually french), not the language of the documents. "
        + "Only output the summary and nothing else. "
        + f"\nOriginal user query: {q}"
        + "\nDocuments:\n"
        + "\n".join([f"{doc.title}\n{doc.content}" for doc in query(q, 3)])
    ).content
    
LLMSummary("Je cherche des docs qui parlent de linguistique")
# Out:
# 'Ces documents couvrent deux sujets distincts liés à la linguistique.  Le premier est une exploration philosophique et pragmatique de notre expérience subjective, de notre rapport au monde et à la communication. Il met l\'accent sur le rôle primordial de l\'expérience vécue dans la construction de notre compréhension du monde, l\'anticipation du futur et l\'interaction avec les autres.  L\'analyse critique du langage, notamment l\'identification des "boucles langagières" (phrases toutes faites déconnectées de l\'expérience) et la promotion d\'un langage plus concret et expérientiel, sont au cœur de cette approche. L\'objectif est de développer une conscience accrue de nos processus mentaux pour mieux s\'aligner sur ses aspirations profondes.\n\nLe second document est une étude linguistique formelle du Khoekhoe, une langue Khoisan.  Il explore la notion d\'« omniprédicativité », où tous les mots peuvent fonctionner comme prédicats. L\'analyse se concentre sur la structure des groupes nominaux (GN) et la prédication dans cette langue.  L\'auteur propose une analyse HPSG (Head-driven Phrase Structure Grammar) démontrant que tous les GN (sauf les marqueurs PGN seuls) sont des propositions relatives libres, formés à partir d\'un prédicat et d\'un marqueur PGN.  L\'analyse inclut une discussion détaillée de la sémantique, en utilisant le cadre de la sémantique des ressources lexicales (LRS), et explore comment les prédicats nominaux complexes sont formés et interprétés.'

# %%
def stream_summary(q: str):
    for tok in ChatGoogleGenerativeAI(
        model="gemini-2.5-flash-preview-05-20",
        temperature=0.7
    ).stream(
        "Summarize the following documents in a single markdown setup. Use markdown freely. "
        + "Use the language of the user query (usually french), not the language of the documents. "
        + "Only output the summary and nothing else. "
        + f"\nOriginal user query: {q}"
        + "\nDocuments:\n"
        + "\n".join([f"{doc.title}\n{doc.content}" for doc in query(q, 3)])
    ):
        yield tok.content
    
for tok in stream_summary("Je cherche des docs qui parlent de linguistique"):
    print(tok, end="", flush=True)
# Out:
# Ce document résume deux textes. Le premier présente une approche phénoménologique et pragmatique de notre rapport au monde, axée sur l'expérience subjective comme matériau premier de la compréhension, de la décision et de l'interaction. Il souligne l'importance de la conscience des mécanismes d'interprétation du passé, d'anticipation du futur et de communication, afin d'identifier les pièges du langage et de la pensée automatique ("boucles langagières") pour mieux s'aligner sur ses aspirations profondes.  Le second texte est un article académique analysant la structure des phrases nominales et la prédication dans la langue Khoekhoe.  Il explore le concept de "langue omniprédicative", où tous les mots peuvent fonctionner comme prédicats. L'analyse propose une approche formelle en HPSG, montrant que les syntagmes nominaux sont dérivés de manière uniforme comme projections d'éléments pronominaux, modifiés par des propositions relatives.  L'article détaille la structure grammaticale de la langue et son analyse sémantique, en utilisant le cadre de la sémantique des ressources lexicales (LRS).
